# %% [markdown]
# # Julia 機器學習：GLM 線性迴歸
#
# ## 作業 027：波士頓房價預測資料集
#
# 請使用 GLM 中的模型，建立一個預測模型來預測波士頓的房價。

# %%
using GLM, RDatasets, MLDataUtils

# %% [markdown]
# ## 讀取資料

# %%
boston = dataset("MASS", "Boston")
first(boston, 10)
# Out:
# 10×14 DataFrame. Omitted printing of 7 columns
# │ Row │ Crim    │ Zn      │ Indus   │ Chas  │ NOx     │ Rm      │ Age     │
# │     │ Float64 │ Float64 │ Float64 │ Int64 │ Float64 │ Float64 │ Float64 │
# ├─────┼─────────┼─────────┼─────────┼───────┼─────────┼─────────┼─────────┤
# │ 1   │ 0.00632 │ 18.0    │ 2.31    │ 0     │ 0.538   │ 6.575   │ 65.2    │
# │ 2   │ 0.02731 │ 0.0     │ 7.07    │ 0     │ 0.469   │ 6.421   │ 78.9    │
# │ 3   │ 0.02729 │ 0.0     │ 7.07    │ 0     │ 0.469   │ 7.185   │ 61.1    │
# │ 4   │ 0.03237 │ 0.0     │ 2.18    │ 0     │ 0.458   │ 6.998   │ 45.8    │
# │ 5   │ 0.06905 │ 0.0     │ 2.18    │ 0     │ 0.458   │ 7.147   │ 54.2    │
# │ 6   │ 0.02985 │ 0.0     │ 2.18    │ 0     │ 0.458   │ 6.43    │ 58.7    │
# │ 7   │ 0.08829 │ 12.5    │ 7.87    │ 0     │ 0.524   │ 6.012   │ 66.6    │
# │ 8   │ 0.14455 │ 12.5    │ 7.87    │ 0     │ 0.524   │ 6.172   │ 96.1    │
# │ 9   │ 0.21124 │ 12.5    │ 7.87    │ 0     │ 0.524   │ 5.631   │ 100.0   │
# │ 10  │ 0.17004 │ 12.5    │ 7.87    │ 0     │ 0.524   │ 6.004   │ 85.9    │

# %%
indecies = MLDataUtils.shuffleobs(collect(1:nrow(boston)))
train_ind, test_ind = MLDataUtils.splitobs(indecies, at = 0.8);

# %%
train = boston[train_ind, :]
test = boston[test_ind, :]
# Out:
# 101×14 DataFrame. Omitted printing of 7 columns
# │ Row │ Crim    │ Zn      │ Indus   │ Chas  │ NOx     │ Rm      │ Age     │
# │     │ Float64 │ Float64 │ Float64 │ Int64 │ Float64 │ Float64 │ Float64 │
# ├─────┼─────────┼─────────┼─────────┼───────┼─────────┼─────────┼─────────┤
# │ 1   │ 0.07151 │ 0.0     │ 4.49    │ 0     │ 0.449   │ 6.121   │ 56.8    │
# │ 2   │ 9.33889 │ 0.0     │ 18.1    │ 0     │ 0.679   │ 6.38    │ 95.6    │
# │ 3   │ 1.05393 │ 0.0     │ 8.14    │ 0     │ 0.538   │ 5.935   │ 29.3    │
# │ 4   │ 0.04337 │ 21.0    │ 5.64    │ 0     │ 0.439   │ 6.115   │ 63.0    │
# │ 5   │ 0.05479 │ 33.0    │ 2.18    │ 0     │ 0.472   │ 6.616   │ 58.1    │
# │ 6   │ 0.12802 │ 0.0     │ 8.56    │ 0     │ 0.52    │ 6.474   │ 97.1    │
# │ 7   │ 45.7461 │ 0.0     │ 18.1    │ 0     │ 0.693   │ 4.519   │ 100.0   │
# │ 8   │ 41.5292 │ 0.0     │ 18.1    │ 0     │ 0.693   │ 5.531   │ 85.4    │
# │ 9   │ 0.09178 │ 0.0     │ 4.05    │ 0     │ 0.51    │ 6.416   │ 84.1    │
# │ 10  │ 6.96215 │ 0.0     │ 18.1    │ 0     │ 0.7     │ 5.713   │ 97.0    │
# ⋮
# │ 91  │ 0.03359 │ 75.0    │ 2.95    │ 0     │ 0.428   │ 7.024   │ 15.8    │
# │ 92  │ 0.01381 │ 80.0    │ 0.46    │ 0     │ 0.422   │ 7.875   │ 32.0    │
# │ 93  │ 0.40202 │ 0.0     │ 9.9     │ 0     │ 0.544   │ 6.382   │ 67.2    │
# │ 94  │ 5.58107 │ 0.0     │ 18.1    │ 0     │ 0.713   │ 6.436   │ 87.9    │
# │ 95  │ 51.1358 │ 0.0     │ 18.1    │ 0     │ 0.597   │ 5.757   │ 100.0   │
# │ 96  │ 0.01709 │ 90.0    │ 2.02    │ 0     │ 0.41    │ 6.728   │ 36.1    │
# │ 97  │ 0.5405  │ 20.0    │ 3.97    │ 0     │ 0.575   │ 7.47    │ 52.6    │
# │ 98  │ 0.3692  │ 0.0     │ 9.9     │ 0     │ 0.544   │ 6.567   │ 87.3    │
# │ 99  │ 0.49298 │ 0.0     │ 9.9     │ 0     │ 0.544   │ 6.635   │ 82.5    │
# │ 100 │ 1.51902 │ 0.0     │ 19.58   │ 1     │ 0.605   │ 8.375   │ 93.9    │
# │ 101 │ 6.39312 │ 0.0     │ 18.1    │ 0     │ 0.584   │ 6.162   │ 97.4    │

# %%
ols = GLM.lm(@formula(Crim ~ Zn + Indus + Chas + NOx + Rm + Age + Dis + Rad + Tax + PTRatio + Black + LStat + MedV), train)
# Out:
# StatsModels.TableRegressionModel{LinearModel{GLM.LmResp{Array{Float64,1}},GLM.DensePredChol{Float64,LinearAlgebra.Cholesky{Float64,Array{Float64,2}}}},Array{Float64,2}}
#
# Crim ~ 1 + Zn + Indus + Chas + NOx + Rm + Age + Dis + Rad + Tax + PTRatio + Black + LStat + MedV
#
# Coefficients:
# ─────────────────────────────────────────────────────────────────────────────────────
#                 Estimate  Std. Error    t value  Pr(>|t|)      Lower 95%    Upper 95%
# ─────────────────────────────────────────────────────────────────────────────────────
# (Intercept)   8.55367     7.52113      1.13729     0.2561   -6.23324      23.3406
# Zn            0.0349067   0.0190551    1.83188     0.0677   -0.00255654    0.07237
# Indus        -0.0485128   0.0827401   -0.586328    0.5580   -0.211184      0.114158
# Chas         -0.511983    1.20494     -0.424902    0.6711   -2.88096       1.857
# NOx          -8.71387     5.62551     -1.54899     0.1222  -19.7739        2.34617
# Rm            1.28934     0.626583     2.05773     0.0403    0.0574429     2.52123
# Age          -0.0088909   0.0188503   -0.471658    0.6374   -0.0459516     0.0281698
# Dis          -0.879481    0.296758    -2.96363     0.0032   -1.46292      -0.29604
# Rad           0.56301     0.0887903    6.3409      <1e-9     0.388444      0.737576
# Tax          -0.002916    0.0050736   -0.574739    0.5658   -0.012891      0.00705896
# PTRatio      -0.25668     0.192613    -1.33262     0.1834   -0.635368      0.122007
# Black        -0.00276008  0.00370832  -0.744294    0.4571   -0.0100508     0.00453066
# LStat         0.160708    0.0816139    1.96913     0.0496    0.000251249   0.321165
# MedV         -0.212448    0.063489    -3.34621     0.0009   -0.33727      -0.0876251
# ─────────────────────────────────────────────────────────────────────────────────────

# %%
predict(ols, test)
# Out:
# 101-element Array{Union{Missing, Float64},1}:
#   0.2839849613853014
#  15.473121781126778
#  -2.045289295369795
#  -0.17738969609723565
#   3.423427803754791
#   1.9565729531891272
#  15.713408695751557
#  14.665526799508887
#   2.148849620393266
#  11.223461311040321
#  10.643650986611808
#   3.9432479227761146
#  -1.2752282890506508
#   ⋮
#   0.47257789512594783
#  -0.46653508773075014
#  -0.8729329389948788
#   0.16659817873770688
#  12.619949584924555
#  12.580429864808545
#  -3.113174465020768
#  -0.41597235260907794
#  -0.15857275806978155
#  -0.33039458188653015
#  -3.412476796387333
#  14.322583108799774
